# %%
import tensorflow as tf
import numpy as np
print('TensorFlow version:', tf.__version__)

# %%
# 0D tensor (scalar)
scalar = tf.constant(7)
print('0D Tensor (scalar):', scalar.numpy(), 'Shape:', scalar.shape)

# %%
# 1D tensor (vector)
vector = tf.constant([1, 2, 3, 4])
print('1D Tensor (vector):', vector.numpy(), 'Shape:', vector.shape)

# %%
# 2D tensor (matrix)
matrix = tf.constant([[1,2,3],[4,5,6]])
print('2D Tensor (matrix):\\n', matrix.numpy(), '\\nShape:', matrix.shape)

# %%
# 3D tensor (cube / single image example)
image = tf.constant([[[255,0,0],[0,255,0]],
                     [[0,0,255],[255,255,0]]])
print('3D Tensor (image):\\n', image.numpy(), '\\nShape:', image.shape)

# %%
# 4D tensor (batch of images)
batch = tf.constant([
  [[[255,0,0],[0,255,0]], [[0,0,255],[255,255,0]]],
  [[[0,255,255],[255,0,255]], [[128,128,128],[0,0,0]]]
])
print('4D Tensor (batch of images):\\n', batch.numpy(), '\\nShape:', batch.shape)

# %%
import matplotlib.pyplot as plt
import numpy as np

def show_tensor(tensor, name):
    shape = tensor.shape
    print(f"{name} shape: {shape}")
    if len(shape) == 0:
        # 0D
        plt.scatter([0], [0], s=500)
        plt.title(f"{name} (0D Scalar)")
        plt.show()
    elif len(shape) == 1:
        # 1D
        plt.bar(range(shape[0]), np.ones(shape[0]))
        plt.title(f"{name} (1D Vector)")
        plt.show()
    elif len(shape) == 2:
        # 2D
        plt.imshow(np.ones(shape), cmap='gray', vmin=0, vmax=1)
        plt.title(f"{name} (2D Matrix)")
        plt.show()
    elif len(shape) == 3:
        # 3D
        fig, axes = plt.subplots(1, shape[0])
        for i in range(shape[0]):
            axes[i].imshow(np.ones(shape[1:]), cmap='gray', vmin=0, vmax=1)
            axes[i].set_title(f"Layer {i}")
        fig.suptitle(f"{name} (3D Tensor)")
        plt.show()
    elif len(shape) == 4:
        # 4D
        batch_size = shape[0]
        fig, axes = plt.subplots(1, batch_size)
        for i in range(batch_size):
            axes[i].imshow(np.ones(shape[1:3]), cmap='gray', vmin=0, vmax=1)
            axes[i].set_title(f"Sample {i}")
        fig.suptitle(f"{name} (4D Batch)")
        plt.show()

# Example usage
show_tensor(scalar, "Scalar")
show_tensor(vector, "Vector")
show_tensor(matrix, "Matrix")
show_tensor(image, "3D Image")
show_tensor(batch, "4D Batch")
